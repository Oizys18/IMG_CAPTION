# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image
image_name = '36979.jpg'
image = Image.open('temp_image\\' + image_name)
image.thumbnail((255, 255), Image.ANTIALIAS)

# %%
# image.thumbnail()
plt.imshow(image)

# %%
import urllib

import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers
AUTOTUNE = tf.data.experimental.AUTOTUNE

import tensorflow_docs as tfdocs
import tensorflow_docs.plots

# import tensorflow_datasets as tfds

import PIL.Image

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (12, 5)

import numpy as np

image_path = 'temp_image\\8251604257.jpg'
image = Image.open(image_path)

# %%
mean = np.mean(image, axis=(0, 1, 2), keepdims=True)
var = np.var(image, axis=(0, 1, 2), keepdims=True)
print(mean, var)
image2 = ((image - mean) / var**0.5)
# print(image2)
plt.imshow(image2)
    
# images = np.asarray(images)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[172.87932]]] [[[2736.4768]]]

# %%
img = plt.imread('temp_image\\8251604257.jpg')
print(img.shape)
mean = img.mean(axis=(0, 1, 2), keepdims=True)
print(mean.shape)
var = img.var(axis=(0, 1, 2), keepdims=True)
print(mean, var)
image2 = ((image - mean) / var**0.5)
# print(image2)
plt.imshow(image2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (500, 500, 3)
# (1, 1, 1)
# [[[172.87931867]]] [[[2736.47666935]]]

# %%
image = tf.constant(img, dtype=tf.float32)
mean, var = tf.nn.moments(image, axes=[0, 1, 2])
centered = (image - mean) / var**0.5
print((image - mean) / var**0.5)
plt.imshow(centered)
plt.show
print('-----------------------------')
img2 = tf.image.per_image_standardization(image)
print(img2)
plt.imshow(img2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor(
# [[[-1.6034634e+00 -3.0355403e-01  8.6254114e-01]
#   [-1.6225797e+00 -3.6090297e-01  8.0519217e-01]
#   [-1.5843470e+00 -3.6090297e-01  8.2430851e-01]
#   ...
#   [-7.4158266e-02  7.8607583e-01  1.1492858e+00]
#   [-5.5041950e-02  8.0519217e-01  1.1684022e+00]
#   [-1.6809324e-02  8.4342480e-01  1.2066348e+00]]
#
#  [[-1.6799287e+00 -3.8001928e-01  7.8607583e-01]
#   [-1.6608123e+00 -3.9913559e-01  7.4784321e-01]
#   [-1.5461144e+00 -3.2267034e-01  8.4342480e-01]
#   ...
#   [-5.5041950e-02  8.0519217e-01  1.1684022e+00]
#   [-3.5925638e-02  8.2430851e-01  1.1875185e+00]
#   [-1.6809324e-02  8.4342480e-01  1.2066348e+00]]
#
#  [[-1.6990449e+00 -3.8001928e-01  7.4784321e-01]
#   [-1.5461144e+00 -2.8443772e-01  8.6254114e-01]
# ...
